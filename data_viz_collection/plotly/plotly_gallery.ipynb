# %% [markdown]
# <a href="https://colab.research.google.com/github/wpan03/quick_ds_python/blob/master/data_viz_collection/plotly/plotly_gallery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
from plotly.subplots import make_subplots
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
data_dict = {
    'metrics': {0: 'value_a', 1: 'value_b', 2: 'value_c'},
    'a': {0: 0.1, 1: 0.01, 2: 0.7},
    'b': {0: 0.2, 1: 0.2, 2: 0.8},
    'c': {0: 0.3, 1: 0.3, 2: 0.9},
    'd': {0: 0.3, 1: 0.4, 2: 0.9},
    'e': {0: 0.05, 1: 0.06, 2: 0.05},
    'f': {0: 0.01, 1: 0.03, 2: 0.2}
}
df = pd.DataFrame(data_dict)

# %%
df
# Out:
#    metrics     a    b    c    d     e     f
# 0  value_a  0.10  0.2  0.3  0.3  0.05  0.01
# 1  value_b  0.01  0.2  0.3  0.4  0.06  0.03
# 2  value_c  0.70  0.8  0.9  0.9  0.05  0.20

# %% [markdown]
# ## Composition - horizontal bar chart

# %%
def generate_bar_group(df: pd.DataFrame, metrics_name: str, y_col: str, color_map: dict, show_legend: bool = True, metric_col: str = 'metrics'):
    bar_list = []
    group_col = list(df.columns[1:])
    df_metric = df.query(f"{metric_col} == '{metrics_name}'").reset_index(drop=True)
    for group in group_col:
        x_val = df_metric.loc[:, group].item()
        bar_tmp = go.Bar(
            y=[y_col],
            x=[x_val],
            name=group,
            orientation='h',
            marker=dict(color=color_map[group]),
            showlegend=show_legend,
            text=f"{x_val:.0%}",
            textposition='inside',
            insidetextanchor='middle',
            textfont=dict(color='white'),
        )
        bar_list.append(bar_tmp)
    return bar_list

# %%
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=('% of value 1', '% of value 2'),
)

color_map = {'a': 'blue', 'b': 'red', 'c': 'green', 'd': 'grey', 'e': 'green', 'f': 'royalblue'}

value_1_bar_list = generate_bar_group(df=df, metrics_name='value_a', y_col='', color_map=color_map)
value_2_bar_list = generate_bar_group(df=df, metrics_name='value_b', y_col='', color_map=color_map, show_legend=False)

fig.add_traces(value_1_bar_list, rows=1, cols=1)
fig.add_traces(value_2_bar_list, rows=2, cols=1)

fig.update_layout(
    barmode='stack',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.2,
        xanchor="center",
        x=0.5,
        title=None,
        traceorder='normal'
    ),
)

# Update axes
for row in [1, 2]:
    fig.update_xaxes(
        range=[0, 1],  # Set the same range for both x-axes
        tickformat='.0%',
        tickmode='linear',
        dtick=1,
        row=row, col=1
    )
    fig.layout.annotations[row-1].update(x=0, xanchor='left', xref='paper')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bc48227d-d15b-4469-b6af-5d737c008d1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc48227d-d15b-4469-b6af-5d737c008d1b")) {                    Plotly.newPlot(                        "bc48227d-d15b-4469-b6af-5d737c008d1b",                        [{"insidetextanchor":"middle","marker":{"color":"blue"},"name":"a","orientation":"h","showlegend":true,"text":"10%","textfont":{"color":"white"},"textposition":"inside","x":[0.1],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"red"},"name":"b","orientation":"h","showlegend":true,"text":"20%","textfont":{"color":"white"},"textposition":"inside","x":[0.2],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"green"},"name":"c","orientation":"h","showlegend":true,"text":"30%","textfont":{"color":"white"},"textposition":"inside","x":[0.3],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"grey"},"name":"d","orientation":"h","showlegend":true,"text":"30%","textfont":{"color":"white"},"textposition":"inside","x":[0.3],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"green"},"name":"e","orientation":"h","showlegend":true,"text":"5%","textfont":{"color":"white"},"textposition":"inside","x":[0.05],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"royalblue"},"name":"f","orientation":"h","showlegend":true,"text":"1%","textfont":{"color":"white"},"textposition":"inside","x":[0.01],"y":[""],"type":"bar","xaxis":"x","yaxis":"y"},{"insidetextanchor":"middle","marker":{"color":"blue"},"name":"a","orientation":"h","showlegend":false,"text":"1%","textfont":{"color":"white"},"textposition":"inside","x":[0.01],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"},{"insidetextanchor":"middle","marker":{"color":"red"},"name":"b","orientation":"h","showlegend":false,"text":"20%","textfont":{"color":"white"},"textposition":"inside","x":[0.2],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"},{"insidetextanchor":"middle","marker":{"color":"green"},"name":"c","orientation":"h","showlegend":false,"text":"30%","textfont":{"color":"white"},"textposition":"inside","x":[0.3],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"},{"insidetextanchor":"middle","marker":{"color":"grey"},"name":"d","orientation":"h","showlegend":false,"text":"40%","textfont":{"color":"white"},"textposition":"inside","x":[0.4],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"},{"insidetextanchor":"middle","marker":{"color":"green"},"name":"e","orientation":"h","showlegend":false,"text":"6%","textfont":{"color":"white"},"textposition":"inside","x":[0.06],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"},{"insidetextanchor":"middle","marker":{"color":"royalblue"},"name":"f","orientation":"h","showlegend":false,"text":"3%","textfont":{"color":"white"},"textposition":"inside","x":[0.03],"y":[""],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9 ...

# %% [markdown]
# ## Comparison - horizontal bar

# %%
fig = make_subplots(
    rows=1, cols=3,
    subplot_titles=('% of value 1', '% of value 2', '% of value 3'),
)

bar_list = []
compare_group = [['a', 'b'], ['c', 'd'], ['e', 'f']]
for group in compare_group:
    y_data = df.loc[df['metrics']=='value_a', group].values.flatten()
    y_text = [f'{x:.0%}' for x in y_data]

    bar = go.Bar(
        x=group,
        y=df.loc[df['metrics']=='value_a', group].values.flatten(),
        orientation='v',
        showlegend=False,
        marker=dict(color='blue'),
        text=y_text,
        textposition='outside',
        textfont=dict(color='black'),
    )
    bar_list.append(bar)

for c in [1, 2, 3]:
    fig.add_traces(bar_list[c-1], rows=1, cols=c)

for annotation in fig['layout']['annotations']:
    annotation['xanchor'] = 'center' #left
    # annotation['x'] -= 0.14

# Update axes
for col in [1, 2, 3]:
    fig.update_yaxes(
        range=[0, 1],
        row=1,
        col=col,
        visible=False,
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09cb41aa-044c-421b-b415-4a0a8da9d6e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09cb41aa-044c-421b-b415-4a0a8da9d6e8")) {                    Plotly.newPlot(                        "09cb41aa-044c-421b-b415-4a0a8da9d6e8",                        [{"marker":{"color":"blue"},"orientation":"v","showlegend":false,"text":["10%","20%"],"textfont":{"color":"black"},"textposition":"outside","x":["a","b"],"y":[0.1,0.2],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue"},"orientation":"v","showlegend":false,"text":["30%","30%"],"textfont":{"color":"black"},"textposition":"outside","x":["c","d"],"y":[0.3,0.3],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"blue"},"orientation":"v","showlegend":false,"text":["5%","1%"],"textfont":{"color":"black"},"textposition":"outside","x":["e","f"],"y":[0.05,0.01],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":" ...
